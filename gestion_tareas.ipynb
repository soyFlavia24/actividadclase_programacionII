# %%
tareas=[encender las luces={"dirigir":"juan","hacer":"eva"},
        cocinar={"lavar":"flavia","salar":"lau"}]
# Out:
#   Cell In[4], line 1
#     tareas=[encender las luces={"dirigir":"juan","hacer":"eva"},
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
